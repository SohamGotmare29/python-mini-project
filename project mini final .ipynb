# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
loan=pd.read_csv('loan.csv')

# %%
df = loan.copy()

# %%
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0      1077501    1296599       5000         5000           4975.0
# 1      1077430    1314167       2500         2500           2500.0
# 2      1077175    1313524       2400         2400           2400.0
# 3      1076863    1277178      10000        10000          10000.0
# 4      1075358    1311748       3000         3000           3000.0
# ...        ...        ...        ...          ...              ...
# 39712    92187      92174       2500         2500           1075.0
# 39713    90665      90607       8500         8500            875.0
# 39714    90395      90390       5000         5000           1325.0
# 39715    90376      89243       5000         5000            650.0
# 39716    87023      86999       7500         7500            800.0
#
#              term int_rate  installment grade emp_length  ...  \
# 0       36 months   10.65%       162.87     B  10+ years  ...
# ...

# %% [markdown]
# ### 2. List down the number of rows and columns.

# %%
df.shape ##there are 39717 row, 23 columns
# Out:
# (39717, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   39717 non-null  int64
#  1   member_id            39717 non-null  int64
#  2   loan_amnt            39717 non-null  int64
#  3   funded_amnt          39717 non-null  int64
#  4   funded_amnt_inv      39717 non-null  float64
#  5   term                 39717 non-null  object
#  6   int_rate             39717 non-null  object
#  7   installment          39717 non-null  float64
#  8   grade                39717 non-null  object
#  9   emp_length           38642 non-null  object
#  10  annual_inc           39717 non-null  float64
#  11  verification_status  39717 non-null  object
#  12  loan_status          39717 non-null  object
#  13  purpose              39717 non-null  object
#  14  dti                  39717 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                    count           mean            std       min        25%  \
# id               39717.0  683131.913060  210694.132915  54734.00  516221.00
# member_id        39717.0  850463.559408  265678.307421  70699.00  666780.00
# loan_amnt        39717.0   11219.443815    7456.670694    500.00    5500.00
# funded_amnt      39717.0   10947.713196    7187.238670    500.00    5400.00
# funded_amnt_inv  39717.0   10397.448868    7128.450439      0.00    5000.00
# installment      39717.0     324.561922     208.874874     15.69     167.02
# annual_inc       39717.0   68968.926377   63793.765790   4000.00   40404.00
# dti              39717.0      13.315130       6.678594      0.00       8.17
# total_pymnt      39717.0   12153.596544    9042.040766      0.00    5576.93
# total_pymnt_inv  39717.0   11567.149118    8942.672613      0.00    5112.31
# total_rec_prncp  39717.0    9793.348813    7065.522127      0.00    4600.00
# ...

# %%
np.mean(df.loc[:,['annual_inc']])
# Out:
# C:\Users\riddh\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3462: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# annual_inc    68968.926377
# dtype: float64

# %% [markdown]
# ### 2. List down the number of rows and columns.

# %%
df.shape
# Out:
# (39717, 23)

# %%
len(df.columns)
# Out:
# 23

# %% [markdown]
# ### 3. ‘Int_rate’ column is character type. With the help of lambda function convert into float type.

# %%
df['int_rate'].apply(lambda x: float(x[:-1]))
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: float64

# %%
df['int_rate']
# Out:
# 0        10.65%
# 1        15.27%
# 2        15.96%
# 3        13.49%
# 4        12.69%
#           ...
# 39712     8.07%
# 39713    10.28%
# 39714     8.07%
# 39715     7.43%
# 39716    13.75%
# Name: int_rate, Length: 39717, dtype: object

# %%
df['int_rate'] = df['int_rate'].apply(lambda x: float(x[:-1]))
df['int_rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: float64

# %%
d={'1':['45.568%','45.5%','98%']}
dft=pd.DataFrame(d)
dft['1']
#d.apply(lambda x : float (x[:-1]))
# Out:
# 0    45.568%
# 1      45.5%
# 2        98%
# Name: 1, dtype: object

# %%
dft['1'].apply(lambda x: float(x[:-1]))
# Out:
# 0    45.568
# 1    45.500
# 2    98.000
# Name: 1, dtype: float64

# %%
df['int_rate']=df['int_rate'].astype(float)

# %% [markdown]
# ### 4. Check the datatype of each column

# %%
df.dtypes
# Out:
# id                       int64
# member_id                int64
# loan_amnt                int64
# funded_amnt              int64
# funded_amnt_inv        float64
# term                    object
# int_rate               float64
# installment            float64
# grade                   object
# emp_length              object
# annual_inc             float64
# verification_status     object
# loan_status             object
# purpose                 object
# dti                    float64
# total_pymnt            float64
# total_pymnt_inv        float64
# total_rec_prncp        float64
# total_rec_int          float64
# last_pymnt_d            object
# last_pymnt_amnt        float64
# Unnamed: 21            float64
# Unnamed: 22            float64
# dtype: object

# %% [markdown]
# ### 5 Cleaning the dataset- Remove the columns having complete NaN value in the entire dataset

# %%
#pandas profiling

# %%
df = df.dropna(axis=1, how='all')

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'emp_length', 'annual_inc',
#        'verification_status', 'loan_status', 'purpose', 'dti', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int', 'last_pymnt_d',
#        'last_pymnt_amnt'],
#       dtype='object')

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#    int_rate  installment grade emp_length  ...  verification_status  \
# 0     10.65       162.87     B  10+ years  ...             Verified
# 1     15.27        59.83     C   < 1 year  ...      Source Verified
# 2     15.96        84.33     C  10+ years  ...         Not Verified
# 3     13.49       339.31     C  10+ years  ...      Source Verified
# 4     12.69        67.79     B     1 year  ...      Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# ...

# %% [markdown]
# ### 6. Write the code to find the value counts of the ‘loan_status’ category column and filter only the ‘fully paid’ and ‘charged off’ categories.

# %%
df.head(4)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
#
#    int_rate  installment grade emp_length  ...  verification_status  \
# 0     10.65       162.87     B  10+ years  ...             Verified
# 1     15.27        59.83     C   < 1 year  ...      Source Verified
# 2     15.96        84.33     C  10+ years  ...         Not Verified
# 3     13.49       339.31     C  10+ years  ...      Source Verified
#
#    loan_status         purpose    dti   total_pymnt  total_pymnt_inv  \
# 0   Fully Paid     credit_card  27.65   5863.155187          5833.84
# 1  Charged Off             car   1.00   1008.710000          1008.71
# ...

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
df1=df[df['loan_status']!='Current']

# %%
df1.value_counts('loan_status')
# Out:
# loan_status
# Fully Paid     32950
# Charged Off     5627
# dtype: int64

# %% [markdown]
# ### 7. Filter the ‘Emp_Len’ column to extract the numerical value from thestring.
# Hint - Emp_len : < 1year, 2 years , 3 years as 1 , 2, 3 so on.

# %%
df.head(3)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
#
#    int_rate  installment grade emp_length  ...  verification_status  \
# 0     10.65       162.87     B  10+ years  ...             Verified
# 1     15.27        59.83     C   < 1 year  ...      Source Verified
# 2     15.96        84.33     C  10+ years  ...         Not Verified
#
#    loan_status         purpose    dti  total_pymnt  total_pymnt_inv  \
# 0   Fully Paid     credit_card  27.65  5863.155187          5833.84
# 1  Charged Off             car   1.00  1008.710000          1008.71
# 2   Fully Paid  small_business   8.72  3005.666844          3005.67
#
#    total_rec_prncp  total_rec_int  last_pymnt_d last_pymnt_amnt
# ...

# %%
df['emp_length'].unique()
# Out:
# array(['10+ years', '< 1 year', '1 year', '3 years', '8 years', '9 years',
#        '4 years', '5 years', '6 years', '2 years', '7 years', nan],
#       dtype=object)

# %%
{'10+ years':10, '< 1 year':1, '1 year':1, '3 years':3, '8 years':8, '9 years':9,
       '4 years':4, '5 years':5, '6 years':6, '2 years':2, '7 years':7, }
# Out:
# {'10+ years': 10,
#  '< 1 year': 1,
#  '1 year': 1,
#  '3 years': 3,
#  '8 years': 8,
#  '9 years': 9,
#  '4 years': 4,
#  '5 years': 5,
#  '6 years': 6,
#  '2 years': 2,
#  '7 years': 7}

# %%
df['emp_length'].replace({'10+ years':10, '< 1 year':1, '1 year':1, '3 years':3, '8 years':8, '9 years':9,
       '4 years':4, '5 years':5, '6 years':6, '2 years':2, '7 years':7, },inplace=True)
# Out:
# C:\Users\riddh\AppData\Local\Temp\ipykernel_14940\3294365683.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['emp_length'].replace({'10+ years':10, '< 1 year':1, '1 year':1, '3 years':3, '8 years':8, '9 years':9,

# %%
df['emp_length'].unique()
# Out:
# array([10.,  1.,  3.,  8.,  9.,  4.,  5.,  6.,  2.,  7., nan])

# %%
df['emp_length']
# Out:
# 0        10.0
# 1         1.0
# 2        10.0
# 3        10.0
# 4         1.0
#          ...
# 39712     4.0
# 39713     3.0
# 39714     1.0
# 39715     1.0
# 39716     1.0
# Name: emp_length, Length: 39717, dtype: float64

# %%
df['emp_length'].value_counts()
# Out:
# 10.0    8879
# 1.0     7823
# 2.0     4388
# 3.0     4095
# 4.0     3436
# 5.0     3282
# 6.0     2229
# 7.0     1773
# 8.0     1479
# 9.0     1258
# Name: emp_length, dtype: int64

# %%
df['emp_length'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### 8. Using the Lambda function, remove the month from the ‘term’ column such that ‘36 months’, ‘60 months’ appear as 36 and 60 respectively.

# %%
df.head(2)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
#
#    int_rate  installment grade  emp_length  ...  verification_status  \
# 0     10.65       162.87     B        10.0  ...             Verified
# 1     15.27        59.83     C         1.0  ...      Source Verified
#
#    loan_status      purpose    dti  total_pymnt  total_pymnt_inv  \
# 0   Fully Paid  credit_card  27.65  5863.155187          5833.84
# 1  Charged Off          car   1.00  1008.710000          1008.71
#
#    total_rec_prncp  total_rec_int  last_pymnt_d last_pymnt_amnt
# 0          5000.00         863.16        Jan-15          171.62
# 1           456.46         435.17        Apr-13          119.66
#
# [2 rows x 21 columns]

# %%
df['term'].unique()
# Out:
# array([' 36 months', ' 60 months'], dtype=object)

# %%
df['term']=df['term'].apply(lambda x: 36 if x==' 36 months' else 60 )
# Out:
# C:\Users\riddh\AppData\Local\Temp\ipykernel_14940\1978118112.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term']=df['term'].apply(lambda x: 36 if x==' 36 months' else 60 )

# %%
df['term'].unique()
# Out:
# array([36, 60], dtype=int64)

# %% [markdown]
# ### 9. Create a new column as risky_loan_applicant by comparing loan_amnt and funded_amnt with the following criteria - If loan_amnt is less than equals to funded_amnt set it as ‘0’ else set it as ‘1’.

# %%
df.head(2)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
#
#    int_rate  installment grade  emp_length  ...  verification_status  \
# 0     10.65       162.87     B        10.0  ...             Verified
# 1     15.27        59.83     C         1.0  ...      Source Verified
#
#    loan_status      purpose    dti  total_pymnt  total_pymnt_inv  \
# 0   Fully Paid  credit_card  27.65  5863.155187          5833.84
# 1  Charged Off          car   1.00  1008.710000          1008.71
#
#    total_rec_prncp  total_rec_int  last_pymnt_d last_pymnt_amnt
# 0          5000.00         863.16        Jan-15          171.62
# 1           456.46         435.17        Apr-13          119.66
#
# [2 rows x 21 columns]

# %%
l=[1,2,46,3,54,9]
m=[4,6,4,23,5,3,54]

for i in l,m:
    if m>l:
        print()

# %%
df[df['loan_amnt']<=df['funded_amnt']]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#        int_rate  installment grade  emp_length  ...  verification_status  \
# ...

# %%
x=df['loan_amnt']==df['funded_amnt']

# %%
x.value_counts()
# Out:
# True     37868
# False     1849
# dtype: int64

# %%
df.apply(lambda x : '0' if x['loan_amnt']>= x['funded_amnt'] else '1',axis=1)
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 39712    0
# 39713    0
# 39714    0
# 39715    0
# 39716    0
# Length: 39717, dtype: object

# %%
df['risky_loan_applicant']=df.apply(lambda x : '0' if x['loan_amnt']<= x['funded_amnt'] else '1',axis=1)
# Out:
# C:\Users\riddh\AppData\Local\Temp\ipykernel_14940\2070914738.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['risky_loan_applicant']=df.apply(lambda x : '0' if x['loan_amnt']<= x['funded_amnt'] else '1',axis=1)

# %%
df['risky_loan_applicant'].unique()
# Out:
# array(['0', '1'], dtype=object)

# %%
l=[]
for i in range (len(df)):
    if df.loc[i,'loan_amnt']<=df.loc[i,'funded_amnt']:
        l.append('1')
    else:
        l.append('0')

# %%
df['risky_loan_applicant1']=l

# %%
df['risky_loan_applicant1'].unique()
# Out:
# array(['1', '0'], dtype=object)

# %%
df['risky_loan_applicant1']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 39712    1
# 39713    1
# 39714    1
# 39715    1
# 39716    1
# Name: risky_loan_applicant1, Length: 39717, dtype: object

# %%
df['risky_loan_applicant'] = 0
df.loc[df['loan_amnt'] > df['funded_amnt'], 'risky_loan_applicant'] = 1

# %%
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
# 2  1077175    1313524       2400         2400           2400.0    36
# 3  1076863    1277178      10000        10000          10000.0    36
# 4  1075358    1311748       3000         3000           3000.0    60
#
#    int_rate  installment grade  emp_length  ...         purpose    dti  \
# 0     10.65       162.87     B        10.0  ...     credit_card  27.65
# 1     15.27        59.83     C         1.0  ...             car   1.00
# 2     15.96        84.33     C        10.0  ...  small_business   8.72
# 3     13.49       339.31     C        10.0  ...           other  20.00
# 4     12.69        67.79     B         1.0  ...           other  17.94
#
#     total_pymnt total_pymnt_inv  total_rec_prncp  total_rec_int  last_pymnt_d  \
# ...

# %% [markdown]
# ### 10. Using the bar plot visualize the loan_status column against categorical column grade, term, verification_status . Write the observation from each graph.

# %%
df.head(2)

# %%
df.groupby(['grade','loan_status']).size().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='grade'>

# %%
df.groupby(['loan_status','term']).size().unstack().plot(kind='bar')
df.groupby(['loan_status', 'verification_status']).size().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='loan_status'>

# %%
df.groupby(['loan_status', 'verification_status']).size().unstack().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='loan_status'>

# %%
df['loan_status'].unique()

# %% [markdown]
# ### 11.Using a user defined function convert the ‘emp_len’ column into categorical column as follows -
# #### If emp_len is less than equals to 1 then recode as ‘fresher’.
# #### If emp_len is greater than 1 and less than 3 then recode as ‘junior’.
# #### If emp_len is greater than 3 and less than 7 then recode as ‘senior’
# #### If emp_len is greater than 7 then recode as ‘expert’.

# %%
def recode_emp_len(emp_length):
    if emp_length <= 1:
        return 'fresher'
    elif 1 < emp_length < 3:
        return 'junior'
    elif 3 < emp_length < 7:
        return 'senior'
    else:
        return 'expert'

    
df['emp_len_category'] = df['emp_length'].apply(recode_emp_len)
df
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0      1077501    1296599       5000         5000           4975.0    36
# 1      1077430    1314167       2500         2500           2500.0    60
# 2      1077175    1313524       2400         2400           2400.0    36
# 3      1076863    1277178      10000        10000          10000.0    36
# 4      1075358    1311748       3000         3000           3000.0    60
# ...        ...        ...        ...          ...              ...   ...
# 39712    92187      92174       2500         2500           1075.0    36
# 39713    90665      90607       8500         8500            875.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
# 39716    87023      86999       7500         7500            800.0    36
#
#        int_rate  installment grade  emp_length  ...    dti   total_pymnt  \
# ...

# %%
df.head(2)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
#
#    int_rate  installment grade  emp_length  ...    dti  total_pymnt  \
# 0     10.65       162.87     B        10.0  ...  27.65  5863.155187
# 1     15.27        59.83     C         1.0  ...   1.00  1008.710000
#
#   total_pymnt_inv total_rec_prncp  total_rec_int  last_pymnt_d  \
# 0         5833.84         5000.00         863.16        Jan-15
# 1         1008.71          456.46         435.17        Apr-13
#
#    last_pymnt_amnt  risky_loan_applicant  risky_loan_applicant1  \
# 0           171.62                     0                      1
# 1           119.66                     0                      1
#
#   emp_len_category
# 0           expert
# 1          fresher
#
# [2 rows x 24 columns]

# %%
df['emp_length'].value_counts()
# Out:
# 10.0    8879
# 1.0     7823
# 2.0     4388
# 3.0     4095
# 4.0     3436
# 5.0     3282
# 6.0     2229
# 7.0     1773
# 8.0     1479
# 9.0     1258
# Name: emp_length, dtype: int64

# %%
df['emp_length'].unique()
# Out:
# array([10.,  1.,  3.,  8.,  9.,  4.,  5.,  6.,  2.,  7., nan])

# %%
df['emp_length']=df['emp_length'].fillna(0).astype(int)

# %%
df['emp_length'].unique()
# Out:
# array([10,  1,  3,  8,  9,  4,  5,  6,  2,  7,  0])

# %%
df.head(2)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 0  1077501    1296599       5000         5000           4975.0    36
# 1  1077430    1314167       2500         2500           2500.0    60
#
#    int_rate  installment grade  emp_length  ...    dti  total_pymnt  \
# 0     10.65       162.87     B          10  ...  27.65  5863.155187
# 1     15.27        59.83     C           1  ...   1.00  1008.710000
#
#   total_pymnt_inv total_rec_prncp  total_rec_int  last_pymnt_d  \
# 0         5833.84         5000.00         863.16        Jan-15
# 1         1008.71          456.46         435.17        Apr-13
#
#    last_pymnt_amnt  risky_loan_applicant  risky_loan_applicant1  \
# 0           171.62                     0                      1
# 1           119.66                     0                      1
#
#   emp_len_category
# 0           expert
# 1          fresher
#
# [2 rows x 24 columns]

# %%
df.groupby('grade')['loan_amnt'].sum()
# Out:
# grade
# A     86982400
# B    133651350
# C     89115825
# D     65160400
# E     45037900
# F     19263100
# G      6391675
# Name: loan_amnt, dtype: int64

# %% [markdown]
# ### 12.Find the sum of ‘loan_amnt’ for each grade and display the distribution of ‘loan_amnt’ using a pie plot.

# %%
x=df.groupby('grade')['loan_amnt'].sum()
x.plot(kind='pie',autopct='%.2f%%')
plt.show()

# %% [markdown]
# #### Extract Potential Borrower Information

# %%
These factors can provide insights into the  financial stability and creditworthiness of the borrowers,
helping us identify potential risk factors. 

dti 35% or less      #The debt-to-income ratio (DTI) is a financial metric that compares a borrower's 
                     #total debt obligations to their gross income.   #df['dti']<=35
    
grade                #A being the highest grade and G being the lowest
                     #with higher grades indicating lower risk and lower grades indicating higher risk.

loan amount          #amount of loan taken 

loan status  -       #paid   #df['loan_status']=='Fully Paid'

emp_length >4 yr     #whether they have a stable source of income for past year  #df['emp_length']>=4

annual_inc           #above the mean salary #df[df['annual_inc']>=df['annual_inc'].mean()]

# %%
df_b=df[(df['dti']<=35) & (df['emp_length']>=4) & (df['annual_inc']>=df['annual_inc'].mean()) 
        & (df['loan_status']=='Fully Paid')]

# %%
dfb=df_b[['id','dti','grade','loan_amnt','loan_status','emp_length','annual_inc']]
dfb.shape
# Out:
# (8197, 7)

# %%
dfb.sort_values(by='grade',ascending=True)
# Out:
#            id    dti grade  loan_amnt loan_status  emp_length  annual_inc
# 19199  679874  22.70     A       8000  Fully Paid          10     81900.0
# 17606  712456   1.68     A       4000  Fully Paid          10     85000.0
# 17652  712144   6.33     A      15000  Fully Paid           6     72000.0
# 17668  711913   9.00     A      12000  Fully Paid          10    150000.0
# 17674  710350  11.02     A      24000  Fully Paid           4     72000.0
# ...       ...    ...   ...        ...         ...         ...         ...
# 17428  710751  21.19     G      20000  Fully Paid          10     69500.0
# 22850  620453  12.82     G      25000  Fully Paid          10     89004.0
# 16389  733401   6.12     G      35000  Fully Paid           5    325000.0
# 10703  825928  16.89     G      35000  Fully Paid          10    106000.0
# 23163  617879   9.46     G      25000  Fully Paid           9    120000.0
#
# [8197 rows x 7 columns]

# %%
df[df['annual_inc']>=df['annual_inc'].mean()]
# Out:
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  term  \
# 4      1075358    1311748       3000         3000           3000.0    60
# 10     1070078    1305201       6500         6500           6500.0    60
# 11     1069908    1305008      12000        12000          12000.0    36
# 14     1069057    1303503      10000        10000          10000.0    36
# 17     1069971    1304884       3600         3600           3600.0    36
# ...        ...        ...        ...          ...              ...   ...
# 39710    92507      92502       5000         5000            250.0    36
# 39711    92402      92390       5000         5000            700.0    36
# 39712    92187      92174       2500         2500           1075.0    36
# 39714    90395      90390       5000         5000           1325.0    36
# 39715    90376      89243       5000         5000            650.0    36
#
#        int_rate  installment grade  emp_length  ...    dti   total_pymnt  \
# ...

# %% [markdown]
# dti 35% or less      #The debt-to-income ratio (DTI) is a financial metric that compares a borrower's
#                      #total debt obligations to their gross income.
# grade                #A being the highest grade and G being the lowest
#                      #with higher grades indicating lower risk and lower grades indicating higher risk.
#
# int_rate
# loan amount
# loan status  - paid
# emp_length >4 yr     #whether they have a stable source of income
# annual_inc           #above the mean salary

# %%
df[['dti','grade','int_rate','loan_amnt','loan_status','emp_length','annual_inc']]

# %% [markdown]
# ### What is purpose of taking loan for people with higher annual income

# %%
df_s=df[df['annual_inc']>=df['annual_inc'].mean()]

# %%
df_s['purpose'].value_counts()
# Out:
# debt_consolidation    6839
# credit_card           2090
# home_improvement      1584
# other                 1274
# small_business         815
# major_purchase         728
# car                    512
# wedding                346
# medical                241
# moving                 165
# house                  164
# vacation               121
# educational             86
# renewable_energy        46
# Name: purpose, dtype: int64

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64

# %%
df['annual_inc']
# Out:
# 0         24000.0
# 1         30000.0
# 2         12252.0
# 3         49200.0
# 4         80000.0
#            ...
# 39712    110000.0
# 39713     18000.0
# 39714    100000.0
# 39715    200000.0
# 39716     22000.0
# Name: annual_inc, Length: 39717, dtype: float64
